# %%
import mtcnn
import argparse
import numpy as np
import os.path
import cv2 
from PIL import Image

from matplotlib import pyplot as plt
# %matplotlib inline

def imshow(tit, image) :
    plt.title(tit)    
    if len(image.shape) == 3 :
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    else :
        plt.imshow(image, cmap="gray")
    plt.show()
# Out:
# Using TensorFlow backend.

# %%
dir_path = './make/'

people_list = os.listdir(dir_path)
people_list
# Out:
# ['19062421', '19062431', '19062521']

# %%
people_name =  '19062421'
people_path = dir_path + people_name

# %%
S_list = os.listdir(people_path)
S_list
# Out:
# ['S001', 'S002', 'S003', 'S004', 'S005', 'S006']

# %%
L_list = ['L1', 'L2', 'L3', 'L4', 'L5']

# %%
E_list = ['E01', 'E02', 'E03']

# %%
C_list = ['C1', 'C2', 'C2']

# %%
img_path_list = []
img_name_list = []

# img_name = 
for people in people_list:
    for s in S_list:
        for l in L_list:
            for e in E_list:
                for c in C_list:
                    img_path = f'{people}/{s}/{l}/{e}/{c}.jpg'
                    img_path_list.append(img_path)
                    img_name = f'{people}_{s}_{l}_{e}_{c}_crop.jpg'
                    img_name_list.append(img_name)

# %%
print(len(img_path_list), img_path_list[1])
# Out:
# 810 19062421/S001/L1/E01/C2.jpg

# %%
print(len(img_name_list), img_name_list[0])
# Out:
# 810 19062421_S001_L1_E01_C1_crop.jpg

# %%
image = np.array(Image.open('./make/' +img_path_list[0]))

# %%
imshow('', image)

# %%
face_cascade= cv2.CascadeClassifier("haarcascade_frontalface_default.xml") 
# eye_cascade= cv2.CascadeClassifier("haarcascade_eye.xml")
# left_eye_cascade=cv2.CascadeClassifier('haarcascade_lefteye_2splits.xml')

# %%
def face_detection(img_path):
    filename = os.path.basename(img_path)
    img = cv2.imread(img_path, 1)
    gray= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
#     eyes = eye_cascade.detectMultiScale(gray)
#     left_eyes = left_eye_cascade.detectMultiScale(gray)

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 255), 2)
        
#     for (x, y, w, h) in eyes:
#         center = (int(x + w / 2), int(y + h / 2))
#         cv2.circle(img, center, int(w/2), (255, 0, 0), 2)
        
#     for (x, y, w, h) in left_eyes:
#         center = (int(x + w / 2), int(y + h / 2))
#         cv2.circle(img, center, int(w/2), (255, 255, 0), 3)

# %%
face_detection('./make/' +img_path_list[0])

# %%
imshow('', img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-8f510d11a679> in <module>
# ----> 1 imshow('', img)
#
# NameError: name 'img' is not defined

# %%
    savepath = f"./images/1_2.{filename}"
    cv2.imwrite(savepath, img) 
    imshow('',img)
    
img_path = '../images/person1.jpg'
face_detection(img_path)
